# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import re
import pickle
import pandas as pd

# %%
all_maharashtra_headlines = []

# %%
for i in range(1,473):
    url = 'https://lokmat.news18.com/category/maharastra/page-' + str(i) + '/'
    req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
    html_doc = ''
    with urlopen(req) as response:
        for line in response:
            line = line.decode('utf-8')
            html_doc = html_doc + line.replace('\n','')
    soup = BeautifulSoup(html_doc, 'html.parser')
    container = soup.find('div',{'id':'rest_bottom_container'})
    blogs = container.find_all('h2')
    for blog in blogs:
        all_maharashtra_headlines.append(blog.text)
    print(len(all_maharashtra_headlines))
# Out:
# 16
# 32
# 48
# 64
# 80
# 96
# 112
# 128
# 144
# 160
# 176
# 192
# 208
# 224
# 240
# 256
# 272
# 288
# 304
# 320
# 336
# 352
# 368
# 384
# 400
# 416
# 432
# 448
# 464
# 480
# 496
# 512
# 528
# 544
# 560
# 576
# 592
# 608
# 624
# 640
# 656
# 672
# 688
# 704
# 720
# 736
# 752
# 768
# 784
# 800
# 816
# 832
# 848
# 864
# 880
# 896
# 912
# 928
# 944
# 960
# 976
# 992
# 1008
# 1024
# 1040
# 1056
# 1072
# 1088
# 1104
# 1120
# 1136
# 1152
# 1168
# 1184
# 1200
# 1216
# 1232
# 1248
# 1264
# 1280
# 1296
# 1312
# 1328
# 1344
# 1360
# 1376
# 1392
# 1408
# 1424
# 1440
# 1456
# 1472
# 1488
# 1504
# 1520
# 1536
# 1552
# 1568
# 1584
# 1600
# 1616
# 1632
# 1648
# 1664
# 1680
# 1696
# 1712
# 1728
# 1744
# 1760
# 1776
# 1792
# 1808
# 1824
# 1840
# 1856
# 1872
# 1888
# 1904
# 1920
# 1936
# 1952
# 1968
# 1984
# 2000
# 2016
# 2032
# 2048
# 2064
# 2080
# 2096
# 2112
# 2128
# 2144
# 2160
# 2176
# 2192
# 2208
# 2224
# 2240
# 2256
# 2272
# 2288
# 2304
# 2320
# 2336
# 2352
# 2368
# 2384
# 2400
# 2416
# 2432
# ...

# %%
all_maharashtra_headlines = list(filter(lambda x: x != s, all_maharashtra_headlines))

# %%
all_maharashtra_headlines = list(set(all_maharashtra_headlines))

# %%
len(all_maharashtra_headlines)
# Out:
# 7547

# %%
all_maharashtra_headlines
# Out:
# ['युतीच्या घोषणेनंतर शिवसेनेची पहिली बैठक; दानवे, सोमय्याविरोध कसा थांबवणार?',
#  "सिंधुदुर्गच्या आखाड्यात रुतले 'बोलेरो'चे चाक !",
#  'हॉटेलच्या पॉर्किंगमधून गाडी चोरीला, चोरी सीसीटीव्हीत कैद',
#  'मुलायम सिंह नवीन पक्ष स्थापन करणार नाहीत',
#  'गाडीतून उतरवताना राॅकेटसारखं उडालं सिलेंडर, ३ कर्मचारी जखमी',
#  'कांद्याच्या निर्यातबंदीवरून स्वाभिमानी शेतकरी संघटना आक्रमक',
#  'अमरावतीत अग्नितांडव, 30 घरं जळून खाक',
#  'SPECIAL REPORT : लातूरमध्ये का करावा लागतोय विद्यार्थ्यांना एसटीने लटकून प्रवास?',
#  'पोलिसांनी चक्क मोबाईल क्रमांकालाच केले आरोपी; वाचा काय आहे प्रकार',
#  'माझी जात विचारू नका, मी छत्रपतींचा मावळा आहे - अमोल कोल्हे',
#  'कर्जतला कुपोषणाचा विळखा, 253 मुलं अति कुपोषित',
#  'पिंपरी चिंचवडमध्ये गुन्हेगारांचा धिंगाणा; वाहन तोडफोडीला पुन्हा सुरुवात',
#  'खंडणी प्रकरणी पीआय धनंजय धुमाळ यांच्या चौकशीचे आदेश',
#  'गप्पा  संगीता चितळेंशी (भाग : 2)',
#  "सरकारची 'मनसे'मदत, राज यांची सभा 'एस.पी'वर हलवली",
#  'हिंजवडीत लेबर कॅम्पचा छज्जा कोसळून एकाचा मृत्यू; तीन गंभीर जखमी',
# ...

# %%
s = "Loading...    (function(){var D=new Date(),d=document,b='body',ce='createElement',ac='appendChild',st='style',ds='display',n='none',gi='getElementById',lp=d.location.protocol,wp=lp.indexOf('http')==0?lp:'https:';var i=d[ce]('iframe');i[st][ds]=n;d[gi]('M370071ScriptRootC286961')[ac](i);try{var iw=i.contentWindow.document;iw.open();iw.writeln('<ht'+'ml><bo'+'dy></bo'+'dy></ht'+'ml>');iw.close();var c=iw[b];}catch(e){var iw=d;var c=d[gi]('M370071ScriptRootC286961');}var dv=iw[ce]('div');dv.id='MG_ID';dv[st][ds]=n;dv.innerHTML=286961;c[ac](dv);var s=iw[ce]('script');s.async='async';s.defer='defer';s.charset='utf-8';s.src=wp+'//jsc.mgid.com/k/a/kannada.news18.com.286961.js?t='+D.getYear()+D.getMonth()+D.getUTCDate()+D.getUTCHours();c[ac](s);})();"

# %%
all_sports_headlines = []

# %%
for i in range(1,78):
    url = 'https://lokmat.news18.com/category/sport/page-' + str(i) + '/'
    req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
    html_doc = ''
    with urlopen(req) as response:
        for line in response:
            line = line.decode('utf-8')
            html_doc = html_doc + line.replace('\n','')
    soup = BeautifulSoup(html_doc, 'html.parser')
    container = soup.find('div',{'id':'rest_bottom_container'})
    blogs = container.find_all('h2')
    for blog in blogs:
        all_sports_headlines.append(blog.text)
    print(len(all_sports_headlines))

# %%
sports_headlines = list(filter(lambda x: x != s, all_sports_headlines))

# %%
len(sports_headlines)
# Out:
# 1222

# %%
sports_headlines
# Out:
# ['VIDEO : रोहितचा विक्रम मोडण्यासाठी ‘हा’ 12 वर्षांचा खेळाडू सज्ज',
#  'IPL 2019 : रणसंग्रामासाठी अखेर ‘थाला’ उतरला मैदानात',
#  "IPL 2019 : मुंबईला पुन्हा चॅम्पियन करण्यासाठी रोहितकडे आहेत 'हुकमी एक्के'",
#  'वाईट सवयींचा गंभीर आरोप, पृथ्वी शॉ म्हणतो...',
#  'IPL 2019 : आरसीबी आतापर्यंत विजेता का नाही? विराटने सांगितलं खरं कारण',
#  'धोनी आणि विराटमध्ये फरक काय? इशांत शर्मा म्हणाला...',
#  '...म्हणून सायनाच्या आजीने तिच्या जन्मानंतर पाहिले नाही तिचे तोंड',
#  'बॅडमिंटन नाही तर, ‘हे’ होतं सायनाचं पहिलं प्रेम',
#  "भारताच्या फुलराणीला 'या' आजारानं जखडलं, उपचारासाठी रुग्णालयात होणार दाखल",
#  '...तर मला वर्ल्डकप संघात नक्की घेतील : अजिंक्य रहाणे',
#  'पुलवामा हल्ल्यातील शहिदांच्या कुटुंबीयांना बीसीसीआय देणार 20 कोटी',
#  '...तरच भारत वर्ल्डकप जिंकेल : रिकी पॉंटिंग',
#  'IPL 2019 : यंदाच्या आयपीएलमध्ये मोडले जातील ‘हे’ चार विक्रम',
#  "IPL 2019 : ज्याला निवृत्तीचा सल्ला दिला जातोय 'तो' त्रिशतकाच्या उंबरठ्यावर",
#  'IPL 2019 :  ख्रिस गेलच्या विक्रमापासून दिग्गज फलंदाजही आहेत दूर',
# ...

# %%
all_entertainment_headlines = []

# %%
for i in range(1,209):
    url = 'https://lokmat.news18.com/category/entertainment/page-' + str(i) + '/'
    req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
    html_doc = ''
    with urlopen(req) as response:
        for line in response:
            line = line.decode('utf-8')
            html_doc = html_doc + line.replace('\n','')
    soup = BeautifulSoup(html_doc, 'html.parser')
    container = soup.find('div',{'id':'rest_bottom_container'})
    blogs = container.find_all('h2')
    for blog in blogs:
        all_entertainment_headlines.append(blog.text)
    print(len(all_entertainment_headlines))
# Out:
# 16
# 32
# 48
# 64
# 80
# 96
# 112
# 128
# 144
# 160
# 176
# 192
# 208
# 224
# 240
# 256
# 272
# 288
# 304
# 320
# 336
# 352
# 368
# 384
# 400
# 416
# 432
# 448
# 464
# 480
# 496
# 512
# 528
# 544
# 560
# 576
# 592
# 608
# 624
# 640
# 656
# 672
# 688
# 704
# 720
# 736
# 752
# 768
# 784
# 800
# 816
# 832
# 848
# 864
# 880
# 896
# 912
# 928
# 944
# 960
# 976
# 992
# 1008
# 1024
# 1040
# 1056
# 1072
# 1088
# 1104
# 1120
# 1136
# 1152
# 1168
# 1184
# 1200
# 1216
# 1232
# 1248
# 1264
# 1280
# 1296
# 1312
# 1328
# 1344
# 1360
# 1376
# 1392
# 1408
# 1424
# 1440
# 1456
# 1472
# 1488
# 1504
# 1520
# 1536
# 1552
# 1568
# 1584
# 1600
# 1616
# 1632
# 1648
# 1664
# 1680
# 1696
# 1712
# 1728
# 1744
# 1760
# 1776
# 1792
# 1808
# 1824
# 1840
# 1856
# 1872
# 1888
# 1904
# 1920
# 1936
# 1952
# 1968
# 1984
# 2000
# 2016
# 2032
# 2048
# 2064
# 2080
# 2096
# 2112
# 2128
# 2144
# 2160
# 2176
# 2192
# 2208
# 2224
# 2240
# 2256
# 2272
# 2288
# 2304
# 2320
# 2336
# 2352
# 2368
# 2384
# 2400
# 2416
# 2432
# ...

# %%
entertainment_headlines = list(filter(lambda x: x != s, all_entertainment_headlines))

# %%
entertainment_headlines = list(set(entertainment_headlines))

# %%
len(entertainment_headlines)
# Out:
# 3323

# %%
entertainment_headlines
# Out:
# ['दीपिकाचं आयुष्यात असणंच माझ्यासाठी सर्व काही - रणवीर',
#  'निकनं प्रियांकाला गिफ्ट दिलेल्या आलिशान घराचे Photos पाहिलेत का?',
#  "KBC 10 : शिपाई ते 'करोडपती', पहा कसा आहे महाराष्ट्राच्या सोनालीचा प्रवास!",
#  '...जेव्हा लता मंगेशकरांना दिलं होतं विष',
#  "विक्रांत सरंजामे घेतोय 'जब वुई मेट'ची मदत",
#  "प्रियांकाचा 'बेवॉच' फक्त प्रौढांसाठी",
#  'लहानपणीची मिस वर्ल्ड मानुषी छिल्लर!',
#  'हाफ गर्लफ्रेंड : मैत्रिणीपेक्षा जास्त,गर्लफ्रेंडपेक्षा कमी',
#  'Kader Khan- लाचार आयुष्याची यशस्वी कहाणी',
#  'जेव्हा पर्ण पेठे सायबर क्राइममध्ये अडकते...',
#  "28 वर्षांनी बाॅलिवूडचे शहेनशहा 'या' अभिनेत्रीसोबत पुन्हा एकदा एकत्र",
#  'इन्शाल्ला!! 10 वर्षांनी सलमान-भन्साळीला मिळालं एकत्र यायचं निमित्त',
#  "कान फिल्म फेस्टिवलमध्ये ऐश्वर्या करणार 'देवदास'चं प्रमोशन",
#  'मराठी बिग बॉसच्या पहिल्या सीझनला आज सुरुवात, कोण असणार या घरात?',
#  'तेव्हाचे राज-सिमरन आणि आज...',
#  "PHOTOS : 'हा' आहे अक्षय कुमारच्या 'गोल्ड'चा खरा चेहरा",
#  "'बाहुबली'ला टक्कर देण्यासाठी 50 देशांत 'ट्युबलाईट' उजळणार",
# ...

# %%
all_headlines = entertainment_headlines + sports_headlines + all_maharashtra_headlines

# %%
len(all_headlines)
# Out:
# 12092

# %%
all_labels = ['entertainment']*len(entertainment_headlines) + ['sports']*len(sports_headlines) + ['state']*len(all_maharashtra_headlines)

# %%
len(all_labels)
# Out:
# 12092

# %%
df = pd.DataFrame({'headline':all_headlines, 'label':all_labels})

# %%
df.tail()
# Out:
#                                                 headline  label
# 12087  धक्कादायक! एक्स्प्रेसमध्ये महिला कोचच्या पायऱ्...  state
# 12088  चर्चा करून तोडगा काढण्यास अण्णा सकारात्मक -गिर...  state
# 12089  जिल्हा बँकांमधील जुन्या नोटा अखेर RBI स्विकारण...  state
# 12090  ज्यांनी आपल्याला मोठं केलं त्यांना विसरू नका, ...  state
# 12091    दाभोलकर कुटुंबीयांनी घेतली पोलीस आयुक्तींची भेट  state

# %%
df.shape
# Out:
# (12092, 2)

# %%
df.to_csv('Marathi_Classification_Data_News_Headlines.csv', index=False)

# %%
df = pd.read_csv('Marathi_Classification_Data_News_Headlines.csv')

# %%
df.tail()
# Out:
#                                                 headline  label
# 12087  धक्कादायक! एक्स्प्रेसमध्ये महिला कोचच्या पायऱ्...  state
# 12088  चर्चा करून तोडगा काढण्यास अण्णा सकारात्मक -गिर...  state
# 12089  जिल्हा बँकांमधील जुन्या नोटा अखेर RBI स्विकारण...  state
# 12090  ज्यांनी आपल्याला मोठं केलं त्यांना विसरू नका, ...  state
# 12091    दाभोलकर कुटुंबीयांनी घेतली पोलीस आयुक्तींची भेट  state
